# %% [markdown]
# <a href="https://colab.research.google.com/github/Dannyhamtar/MachineLearning/blob/main/Task%20week%206/Clustering%20SKLearn/5_Hierarchical_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Danny Hamtar Pangestu / 1103210037 / Hierarchical clustering
#
# Demo Hierarchical clustering : Clustering algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram

# Generate synthetic data (blobs)
X, _ = make_blobs(n_samples=300, centers=4, cluster_std=0.6, random_state=42)

# Visualize the original data
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c='b', marker='o', s=30)
plt.title('Original Data')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.grid(True)
plt.show()

# Apply Hierarchical Clustering (Agglomerative)
n_clusters = 4  # Number of clusters
agg_clustering = AgglomerativeClustering(n_clusters=n_clusters)
cluster_labels = agg_clustering.fit_predict(X)

# Visualize the clusters
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=cluster_labels, marker='o', s=30, cmap='viridis')
plt.title('Hierarchical Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.grid(True)
plt.show()

# Plot dendrogram (optional)
from scipy.cluster.hierarchy import linkage

linkage_matrix = linkage(X, method='ward')
plt.figure(figsize=(12, 8))
dendrogram(linkage_matrix)
plt.title('Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()
