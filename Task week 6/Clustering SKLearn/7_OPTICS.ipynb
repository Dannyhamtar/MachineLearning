# %% [markdown]
# <a href="https://colab.research.google.com/github/Dannyhamtar/MachineLearning/blob/main/Task%20week%206/Clustering%20SKLearn/7_OPTICS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Danny Hamtar Pangestu / 1103210037 / OPTICS
#
# Demo OPTICS Clustering algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.cluster import OPTICS

# Generate synthetic data (two moons)
X, _ = make_moons(n_samples=300, noise=0.1, random_state=42)

# Apply OPTICS
clusterer = OPTICS(min_samples=5, xi=0.05, min_cluster_size=0.05)
clusterer.fit(X)

# Extract cluster labels
cluster_labels = clusterer.labels_

# Visualize the clusters
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=cluster_labels, marker='o', s=30, cmap='viridis')
plt.title('OPTICS Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.grid(True)
plt.show()
