# %% [markdown]
# <a href="https://colab.research.google.com/github/Dannyhamtar/MachineLearning/blob/main/Task%20week%206/Clustering%20SKLearn/8_BIRCH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Danny Hamtar Pangestu / 1103210037 / BIRCH**
#
#  Demo BIRCH clustering : Clustering algorithm

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.cluster import Birch

# Generate synthetic data (two moons)
X, _ = make_moons(n_samples=300, noise=0.1, random_state=42)

# Apply BIRCH
clusterer = Birch(n_clusters=2)
cluster_labels = clusterer.fit_predict(X)

# Visualize the clusters
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=cluster_labels, marker='o', s=30, cmap='viridis')
plt.title('BIRCH Clustering')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.grid(True)
plt.show()
